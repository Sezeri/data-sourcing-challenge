# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ###
# Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"
# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
query_url = f"{url}&api-key={nyt_api_key}&fq={filter_query}&begin_date={begin_date}&end_date={end_date}&sort={sort}&fl={field_list}"
print(query_url)
# Out:
# https://api.nytimes.com/svc/search/v2/articlesearch.json?&api-key=mxAWJkGuKYGipYz9rs46En9nMArspYzD&fq=section_name:"Movies" AND type_of_material:"Review" AND headline:"love"&begin_date=20130101&end_date=20230531&sort=newest&fl=headline,web_url,snippet,source,keywords,pub_date,byline,word_count

# %%
# Create an empty list to store the reviews
reviews_list = []
# loop through pages 0-19
for page_num in range(20):
   # create query with a page number
    # API results show 10 articles at a time
    new_query = f"{query_url}&page={page_num}"
   
   # Make a "GET" request and retrieve the JSON
    reviews = requests.get(new_query).json()
    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    try:
        #reviews["response"]["docs"]
        
        # loop through the reviews["response"]["docs"] and append each review to the list
        for review in reviews["response"]["docs"]:
            reviews_list.append(review)
        # Print the page that was just retrieved
        print(f"Page number {page_num} was just retrieved")
    except:
       # Print the page number that had no results then break from the loop
        print(f"No result from Page number {page_num}")
        break
# Out:
# Page number 0 was just retrieved
# Page number 1 was just retrieved
# Page number 2 was just retrieved
# Page number 3 was just retrieved
# Page number 4 was just retrieved
# Page number 5 was just retrieved
# Page number 6 was just retrieved
# Page number 7 was just retrieved
# Page number 8 was just retrieved
# Page number 9 was just retrieved
# Page number 10 was just retrieved
# Page number 11 was just retrieved
# Page number 12 was just retrieved
# Page number 13 was just retrieved
# Page number 14 was just retrieved
# Page number 15 was just retrieved
# Page number 16 was just retrieved
# Page number 17 was just retrieved
# Page number 18 was just retrieved
# Page number 19 was just retrieved

# %%
new_query = f"{query_url}&page={1}"
   
   # Make a "GET" request and retrieve the JSON
reviews = requests.get(new_query).json()
#reviews["response"]["docs"]
#type(reviews)
#type(reviews["response"]["docs"])

# %%
#response = requests.get(query_url)
#response_json = response.json()
#print(json.dumps(response_json[:5], indent=4))
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data

#data_list = list(response_json.items())[:5]
print(json.dumps(reviews_list[:5], indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
# ...

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
#reviews_list_df = pd.DataFrame(reviews_list)
reviews_normalized_df = pd.json_normalize(reviews_list)
reviews_normalized_df

#expected_columns = ['web_url', 'snippet', 'source', 'keywords', 'pub_date', 'word_count', 'headline.main', 'headline.kicker', 'headline.content_kicker', 'headline.print_headline', 'headline.name', 'headline.seo', 'headline.sub', 'byline.original', 'byline.person', 'byline.organization']
#if all(col in reviews_normalized_df.columns for col in expected_columns):
    #print("DataFrame columns match the expected columns.")
#else:
    #print("DataFrame columns do not match the expected columns.")

# Display the normalized DataFrame
#print(reviews_normalized_df)
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# ...

# %%
# Here, "reviews_normalized_df" has been renamed "df1" to avoid over-stacking of the data frame.
df1 = pd.json_normalize(reviews_list)
df1
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# ...

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
df1['title'] = df1["headline.main"].apply(lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")])
df1
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# ...

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
reviews_normalized_df['keywords'] = reviews_normalized_df['keywords'].apply(extract_keywords)

# %%
# Fix the "keywords" column by converting cells from a list to a string
df1['keywords'] = df1['keywords'].apply(extract_keywords)

# %%
df1
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# ...

# %%
reviews_normalized_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# ...

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
titles = df1['title'].to_list()

# %%
titles
# Out:
# ['The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'About Fate',
#  'Waiting for Bojangles',
#  'I Love My Dad',
#  'A Love Song',
#  'Alone Together',
#  'Art of Love',
#  'The Wheel',
#  'Thor: Love and Thunder',
#  'Both Sides of the Blade',
#  'Fire of Love',
#  'Love & Gelato',
#  'Stay Prayed Up',
#  'Benediction',
#  'Dinner in America',
#  'In a New York Minute',
#  'Anaïs in Love',
#  'I Love America',
#  'See You Then',
#  'La Mami',
#  'Love After Love',
#  'Deep Water',
#  'Lucy and Desi',
# ...

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
# Create an empty list to store the results
tmdb_movies_list = []

# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 1
# Loop through the titles
for title in titles:
    # Simulating multiple of 50 requests
    m = input("What multiple of 50 would you like to process?")
    # This is to turn the user's input into an integer
    m = int(m)
    #while i in range(1, 50*m):
        # Check if we need to sleep before making a request
    if request_counter % 50*m == 0:
        print("The application is sleeping for 1 second...")
        # This is to put in a one second sleep timer
        time.sleep(1)
        # This is to validate the user's input and ensurte it is a valid multiple factor
        break
    while m < 1:
        #This is to tell the user they entered an invalind input
        print ("You must enter a multiple factor greater than or equal to 1. Please try again.")
        # This to to relaunch the user to try again
        m = input("What multiple of 50 would you like to process?")
        # This is to turn the user's input into an integer; and when this is correct, process the request and update the counter by one increment.
        m = int(m)
    if m >=1:
        for i in range(1, 50 * m + 1):
            print(f"Request {i} sent for title: {title}")
            tmdb_movies_list.append(title)
            # Update the title variable to the next title before the next iteration
            if titles.index(title) < len(titles) - 1:
                title = titles[titles.index(title) + 1]
                request_counter += 1

    # Display all the titles after all requests are processed
    print("All titles after requests:")
    for title in tmdb_movies_list:
        print(title)
    print("All request are processed.")
    break

  # Perform a "GET" request for The Movie Database
response = requests.get(f"https://api.themoviedb.org/3/movie?query={title}&api_key={tmdb_api_key}")
# Retrieve the JSON results
#results = response.json()

    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.

        # Get movie id
try:
        # Get the movie ID from the first result
        movie_id = results['results'][0]['id']


        # Make a request for a the full movie details
        movie_response = requests.get(f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb_api_key}")

        # Execute "GET" request with url
        # Retrieve the full movie details in JSON format
        movie_details = movie_response.json()

        
        # Extract the genre names into a list
        genres = [genre['name'] for genre in movie_details['genres']]

        # Extract the spoken_languages' English name into a list
        spoken_languages = [lang['english_name'] for lang in movie_details['spoken_languages']]

        # Extract the production_countries' name into a list
        production_countries = [country['name'] for country in movie_details['production_countries']]

        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list
    # Create a dictionary with relevant data
        movie_data = {
            'title': movie_details['title'],
            'original_title': movie_details['original_title'],
            'budget': movie_details['budget'],
            'original_language': movie_details['original_language'],
            'homepage': movie_details['homepage'],
            'overview': movie_details['overview'],
            'popularity': movie_details['popularity'],
            'runtime': movie_details['runtime'],
            'revenue': movie_details['revenue'],
            'release_date': movie_details['release_date'],
            'vote_average': movie_details['vote_average'],
            'vote_count': movie_details['vote_count'],
            'genres': genres,
            'spoken_languages': spoken_languages,
            'production_countries': production_countries
                    }
     # Append the dictionary to tmdb_movies_list list
        tmdb_movies_list.append(movie_data)
        tmdb_movies_list
                
       # Print out the title that was found
        print("The title that was found")
except:
        print(f"Movie not found for title: {title}")
        #break
# Out:
# What multiple of 50 would you like to process? 1
# Request 1 sent for title: The Attachment Diaries
# Request 2 sent for title: What’s Love Got to Do With It?’ Probably a Lo
# Request 3 sent for title: You Can Live Forever
# Request 4 sent for title: A Tourist’s Guide to Love
# Request 5 sent for title: Other People’s Children
# Request 6 sent for title: One True Loves
# Request 7 sent for title: The Lost Weekend: A Love Story
# Request 8 sent for title: A Thousand and One
# Request 9 sent for title: Your Place or Mine
# Request 10 sent for title: Love in the Time of Fentanyl
# Request 11 sent for title: Pamela, a Love Story
# Request 12 sent for title: In From the Side
# Request 13 sent for title: After Love
# Request 14 sent for title: Alcarràs
# Request 15 sent for title: Nelly & Nadine
# Request 16 sent for title: Lady Chatterley’s Lover
# Request 17 sent for title: The Sound of Christmas
# Request 18 sent for title: The Inspection
# Request 19 sent for title: Bones and All
# ...

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
json_results = json.dumps(response[:5], indent=4)
# Replace the Unicode character with a regular single quote
#json_string = json_string.replace('\\u2019', "'")
# Print the result
print(json_results)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[114], line 3
#       1 # Preview the first 5 results in JSON format
#       2 # Use json.dumps with argument indent=4 to format data
# ----> 3 json_results = json.dumps(response[:5], indent=4)
#       4 # Replace the Unicode character with a regular single quote
#       5 #json_string = json_string.replace('\\u2019', "'")
#       6 # Print the result
#       7 print(json_results)
#
# TypeError: 'Response' object is not subscriptable

# %%
# Convert the results to a DataFrame
# Create a DataFrame from the 'results' data
tmdb_df = pd.DataFrame(tmdb_movies_list, columns=['0'])

# Display the DataFrame
#print("Before renaming:")
print(tmdb_df)

# Rename the column
#renamed_df = df_results.rename(columns={"0": "title"})

# Print the renamed DataFrame
#print("\nAfter renaming:")
#print(renamed_df)
# Out:
#                                                 0
# 0                          The Attachment Diaries
# 1   What’s Love Got to Do With It?’ Probably a Lo
# 2                            You Can Live Forever
# 3                       A Tourist’s Guide to Love
# 4                         Other People’s Children
# 5                                  One True Loves
# 6                  The Lost Weekend: A Love Story
# 7                              A Thousand and One
# 8                              Your Place or Mine
# 9                    Love in the Time of Fentanyl
# 10                           Pamela, a Love Story
# 11                               In From the Side
# 12                                     After Love
# 13                                       Alcarràs
# 14                                 Nelly & Nadine
# 15                        Lady Chatterley’s Lover
# 16                         The Sound of Christmas
# 17                                 The Inspection
# ...

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Check the column names of the New York Times reviews DataFrame
#print("Columns in NYT Reviews DataFrame:")
print(df1.columns)
# Out:
# Index(['web_url', 'snippet', 'source', 'keywords', 'pub_date', 'word_count',
#        'headline.main', 'headline.kicker', 'headline.content_kicker',
#        'headline.print_headline', 'headline.name', 'headline.seo',
#        'headline.sub', 'byline.original', 'byline.person',
#        'byline.organization', 'title'],
#       dtype='object')

# %%
# Check the column names of the TMDB DataFrame
#print("\nColumns in TMDB DataFrame:")
print(df_results.columns)
# Out:
# Index(['0'], dtype='object')

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
merged_data = pd.merge(df1, df_results, on='title', how='inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21152\1886772851.py in ?()
#       1 # Merge the New York Times reviews and TMDB DataFrames on title
# ----> 2 merged_data = pd.merge(df1, df_results, on='title', how='inner')
#
# ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     165             validate=validate,
#     166             copy=copy,
#     167         )
#     168     else:
# --> 169         op = _MergeOperation(
#     170             left_df,
#     171             right_df,
#     172             how=how,
#
# ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
# ...

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing


# Create a list of characters to remove


# Loop through the list of columns to fix

    # Convert the column to type 'str'


    # Loop through characters to remove


# Display the fixed DataFrame

# %%
# Drop "byline.person" column

# %%
# Delete duplicate rows and reset index

# %%
# Export data to CSV without the index
